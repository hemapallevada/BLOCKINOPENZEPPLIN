# %% [markdown]
# <a href="https://colab.research.google.com/github/hemapallevada/BLOCKINOPENZEPPLIN/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn. datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
data=load_iris()
print('Classes to predict:',data.target_names)
# Out:
# Classes to predict: ['setosa' 'versicolor' 'virginica']

# %%
X=data.data
y=data.target
print("Number of records in dataset:",X.shape[0])
print(X[:4])
# Out:
# Number of records in dataset: 150
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]]

# %%
X_train,X_test,y_train, y_test=train_test_split(X,y,random_state=22, test_size=0.45)

# %%
clf=DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred=clf.predict(X_test)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
plt.figure(figsize = (20,20))
plot_tree(clf,filled=True)
plt.show()
